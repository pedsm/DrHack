# %% [markdown]
# # Exploratory analysis on eprints
#
# Eprints is a dataset of published papers at the university of nottingham.

# %%
import pandas as pd

df = pd.read_json('eprints-articles.json').head(5)
df.head(5)
# Out:
#                                             abstract  \
# 0  Lawrence and Giles [1] eloquently define the c...
# 1  This paper discusses the advantages of databas...
# 2  This paper aims to provide an overview of digi...
# 3  The evaluation of relativistic spin networks p...
# 4  This paper reviews the construction of quantum...
#
#                               authors     date  \
# 0                     [Gardner, Mike]  1999-09
# 1  [Gardner, Mike, Pinfield, Stephen]  2001-01
# 2                 [Pinfield, Stephen]     1999
# 3   [Barrett, John W., Baez, John C.]     2001
# 4                  [Barrett, John W.]     2000
#
#                            divisions  eprintid funders  \
# 0             [Information Services]         1      []
# 1             [Information Services]         4      []
# 2             [Information Services]         5      []
# 3  [School of Mathematical Sciences]         7      []
# 4  [School of Mathematical Sciences]         8      []
#
# ...

# %%
df.groupby('divisions')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-7faac505a004> in <module>()
# ----> 1 df.groupby('divisions').plot()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby.py in __call__(self, *args, **kwargs)
#     471             return self.plot(*args, **kwargs)
#     472         f.__name__ = 'plot'
# --> 473         return self._groupby.apply(f)
#     474
#     475     def __getattr__(self, name):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     803         # ignore SettingWithCopy here in case the user mutates
#     804         with option_context('mode.chained_assignment', None):
# --> 805             return self._python_apply_general(f)
#     806
#     807     def _python_apply_general(self, f):
#
# ...
